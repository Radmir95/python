# %%
"Hello world"
# Out:
# 'Hello world'

# %%
t = "Hello world!"

# %%
t
# Out:
# 'Hello world!'

# %% [markdown]
# $$ c = {a^2 + b^2} $$

# %%
! echo $t
# Out:
# Hello world!

# %%
! ls
# Out:
# "ls" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
! help
# Out:
# „«п Ї®«гзҐ­Ёп бўҐ¤Ґ­Ё© ®Ў ®ЇаҐ¤Ґ«Ґ­­®© Є®¬ ­¤Ґ ­ ЎҐаЁвҐ HELP <Ё¬п Є®¬ ­¤л>
# ASSOC          ‚лў®¤ «ЁЎ® Ё§¬Ґ­Ґ­ЁҐ б®Ї®бв ў«Ґ­Ё© Ї® а биЁаҐ­Ёп¬ Ё¬Ґ­ д ©«®ў.
# ATTRIB         Ћв®Ўа ¦Ґ­ЁҐ Ё Ё§¬Ґ­Ґ­ЁҐ  ваЁЎгв®ў д ©«®ў.
# BREAK        ‚Є«озҐ­ЁҐ Ё ўлЄ«озҐ­ЁҐ аҐ¦Ё¬  ®Ўа Ў®вЄЁ Є®¬ЎЁ­ жЁЁ Є« ўЁи CTRL+C.
# BCDEDIT        ‡ ¤ Ґв бў®©бвў  ў Ў §Ґ ¤ ­­ле § Јаг§ЄЁ ¤«п гЇа ў«Ґ­Ёп ­ з «м­®©
#                § Јаг§Є®©.
# CACLS          Ћв®Ўа ¦Ґ­ЁҐ Ё аҐ¤ ЄвЁа®ў ­ЁҐ бЇЁбЄ®ў гЇа ў«Ґ­Ёп ¤®бвгЇ®¬ (ACL)
#                Є д ©« ¬.
# CALL           ‚л§®ў ®¤­®Ј® Ї ЄҐв­®Ј® д ©«  Ё§ ¤агЈ®Ј®.
# CD             ‚лў®¤ Ё¬Ґ­Ё «ЁЎ® б¬Ґ­  вҐЄгйҐ© Ї ЇЄЁ.
# CHCP           ‚лў®¤ «ЁЎ® гбв ­®ўЄ   ЄвЁў­®© Є®¤®ў®© бва ­Ёжл.
# CHDIR          ‚лў®¤ Ё¬Ґ­Ё «ЁЎ® б¬Ґ­  вҐЄгйҐ© Ї ЇЄЁ.
# CHKDSK         Џа®ўҐаЄ  ¤ЁбЄ  Ё ўлў®¤ бв вЁбвЁЄЁ.
# CHKNTFS        Ћв®Ўа ¦Ґ­ЁҐ Ё«Ё Ё§¬Ґ­Ґ­ЁҐ ўлЇ®«­Ґ­Ёп Їа®ўҐаЄЁ ¤ЁбЄ  ў® ўаҐ¬п
#                § Јаг§ЄЁ.
# CLS            ЋзЁбвЄ  нЄа ­ .
# ...

# %%
(190**4 - 120/0.3)*1780
# Out:
# 2319713088000.0
